# %% [markdown]
# <a href="https://colab.research.google.com/github/tanaya48/AIR-MONITORING-ANALYSIS-SRPINT1-/blob/main/AIR_QUALITY_MONITORING_ANALYSIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***PROJECT-AIR QUALITY MONITORING ANALYSIS***

# %% [markdown]
# DEVELOPED BY TANAYA SHETE

# %% [markdown]
# PROBLEM STATEMENT-
# The goal of this analysis is to explore, clean, and visualize the air quality dataset to identify patterns and relationships among different environmental variables such as ozone levels, wind speed, temperature, and solar radiation.

# %% [markdown]
# Objective-
#
# 1.  The main objective of this project is to analyze the air quality dataset to gain insights into environmental factors such as ozone levels, wind speed, temperature, and solar radiation.
# 2.   Data Cleaning and Preprocessing
# 3.   Correlation Analysis
# 2.   Trend Analysis

# %% [markdown]
# Dataset Overview:
# The dataset contains 153 entries with the following columns:
#
# Ozone: Ozone concentration levels (parts per billion).
#
# Solar.R: Solar radiation in the atmosphere (langley).
#
# Wind: Wind speed (mph).
#
# Temp: Temperature (°F).
#
# Month: Recorded month (integer format).
#
# Day: Recorded day (integer format).

# %% [markdown]
# Github Link
#
# *   https://github.com/tanaya48/Air-Quality-Monitoring

# %% [markdown]
# LIBRARIES USED

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Insights-Installed all necessary packages

# %% [markdown]
# LOADING THE CSV FILE FROM THE SYSTEM

# %%
# Load the air quality dataset - make sure the file path is correct!
df = pd.read_csv('/content/airquality.csv')  # Update with correct path if needed

# %% [markdown]
# Insight: Loading the file from local system

# %% [markdown]
# DATA SET VIEW

# %%
# View the first few rows of the dataset to understand its structure
print("Original Data:")
print(df.head())
# Out:
# Original Data:
#    rownames  Ozone  Solar.R  Wind  Temp  Month  Day
# 0         1   41.0    190.0   7.4    67      5    1
# 1         2   36.0    118.0   8.0    72      5    2
# 2         3   12.0    149.0  12.6    74      5    3
# 3         4   18.0    313.0  11.5    62      5    4
# 4         5    NaN      NaN  14.3    56      5    5

# %% [markdown]
# Insights-First few rows of the data set are displayed

# %% [markdown]
# DATA SET INFORMATION

# %%
import pandas as pd

# Get dataset information
print("Dataset Information:")
df.info()
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   rownames  153 non-null    int64
#  1   Ozone     116 non-null    float64
#  2   Solar.R   146 non-null    float64
#  3   Wind      153 non-null    float64
#  4   Temp      153 non-null    int64
#  5   Month     153 non-null    int64
#  6   Day       153 non-null    int64
# dtypes: float64(3), int64(4)
# memory usage: 8.5 KB

# %% [markdown]
# Insights-Information of dataset was given

# %%
import pandas as pd

# Load the dataset (replace 'your_dataset.csv' with your actual file)
data = pd.read_csv('/content/airquality.csv')

# Display the first 5 rows
print(data.head(5))
# Out:
#    rownames  Ozone  Solar.R  Wind  Temp  Month  Day
# 0         1   41.0    190.0   7.4    67      5    1
# 1         2   36.0    118.0   8.0    72      5    2
# 2         3   12.0    149.0  12.6    74      5    3
# 3         4   18.0    313.0  11.5    62      5    4
# 4         5    NaN      NaN  14.3    56      5    5

# %% [markdown]
# Insights-This shows the First 5 rows of dataset

# %%
import pandas as pd

# Load the dataset (replace 'your_dataset.csv' with your actual file)
data = pd.read_csv('/content/airquality.csv')

# Display the last 5 rows
print(data.tail(5))
# Out:
#      rownames  Ozone  Solar.R  Wind  Temp  Month  Day
# 148       149   30.0    193.0   6.9    70      9   26
# 149       150    NaN    145.0  13.2    77      9   27
# 150       151   14.0    191.0  14.3    75      9   28
# 151       152   18.0    131.0   8.0    76      9   29
# 152       153   20.0    223.0  11.5    68      9   30

# %% [markdown]
# Insights-This shows the last 5 rows of dataset

# %%
import pandas as pd

# Find the total rows and columns
total_rows = df.shape[0]
total_columns = df.shape[1]

print("Total Rows:", total_rows)
print("Total Columns:", total_columns)
# Out:
# Total Rows: 153
# Total Columns: 7

# %% [markdown]
# Insights-This shows the total number of rows and columns in the dataset.

# %% [markdown]
# DATA CLEANING
#
# *   Missing value

# %%
# Check for missing values
print("\nMissing Values Before Cleaning:")
print(df.isnull().sum())
# Out:
# Missing Values Before Cleaning:
# rownames     0
# Ozone       37
# Solar.R      7
# Wind         0
# Temp         0
# Month        0
# Day          0
# dtype: int64

# %% [markdown]
# Insight-Missing values were found in datset

# %% [markdown]
# Filling the missing value

# %%
import pandas as pd



# Display the DataFrame before filling missing values
print("DataFrame before filling missing values:")
print(df)

# Fill missing values with the mean of the respective columns (only for numeric columns)
df[df.select_dtypes(include=['number']).columns] = df.select_dtypes(include=['number']).fillna(df.mean())

# Display the DataFrame after filling missing values
print("\nDataFrame after filling missing values:")
print(df)

# Optionally, save the DataFrame back to a CSV file
df.to_csv('your_file_filled.csv', index=False)
# Out:
# DataFrame before filling missing values:
#      rownames  Ozone  Solar.R  Wind  Temp  Month  Day
# 0           1   41.0    190.0   7.4    67      5    1
# 1           2   36.0    118.0   8.0    72      5    2
# 2           3   12.0    149.0  12.6    74      5    3
# 3           4   18.0    313.0  11.5    62      5    4
# 4           5    NaN      NaN  14.3    56      5    5
# ..        ...    ...      ...   ...   ...    ...  ...
# 148       149   30.0    193.0   6.9    70      9   26
# 149       150    NaN    145.0  13.2    77      9   27
# 150       151   14.0    191.0  14.3    75      9   28
# 151       152   18.0    131.0   8.0    76      9   29
# 152       153   20.0    223.0  11.5    68      9   30
#
# [153 rows x 7 columns]
#
# DataFrame after filling missing values:
#      rownames     Ozone     Solar.R  Wind  Temp  Month  Day
# 0           1  41.00000  190.000000   7.4    67      5    1
# 1           2  36.00000  118.000000   8.0    72      5    2
# ...

# %% [markdown]
# Checking the missing value after cleaning

# %%
# Check for missing values after cleaning
print("\nMissing Values After Cleaning:")
print(df.isnull().sum())
# Out:
# Missing Values After Cleaning:
# rownames    0
# Ozone       0
# Solar.R     0
# Wind        0
# Temp        0
# Month       0
# Day         0
# dtype: int64

# %% [markdown]
# Insights-Missing values were checked after cleaning

# %% [markdown]
# UNIQUE VALUES FOR EACH VARIABLE

# %%
import pandas as pd
# Check unique values for each variable
unique_values = df.nunique()

# Print the unique values for each variable
print("Unique Values for Each Variable:")
print(unique_values)
# Out:
# Unique Values for Each Variable:
# rownames    153
# Ozone        68
# Solar.R     118
# Wind         31
# Temp         40
# Month         5
# Day          31
# dtype: int64

# %% [markdown]
# Imsoght-Unique values in dataset were checked

# %% [markdown]
# DATA VISUALISATION

# %% [markdown]
# PIE CHART OF DISTRIBUTION OF OZONE LEVELS

# %%
# --- Pie Chart: Distribution of 'Ozone' Levels ---
# Categorize 'Ozone' levels for pie chart visualization
df['Ozone_Category'] = pd.cut(df['Ozone'], bins=[0, 20, 40, 60, 100, 200], labels=['Very Low', 'Low', 'Moderate', 'High', 'Very High'])

plt.figure(figsize=(8, 6))
ozone_counts = df['Ozone_Category'].value_counts()
plt.pie(ozone_counts, labels=ozone_counts.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
plt.title('Ozone Level Distribution')
plt.show()

# %% [markdown]
# *Insight-The pie chart shows the distribution of ozone levels in a given dataset. The x-axis represents the different ozone categories, while the y-axis represents the percentage of data points falling into each category.*

# %% [markdown]
# BOX PLOT OF WIND AND TEMPRATURE

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Calculate the average Ozone levels by Month
average_ozone_by_month = df.groupby('Month')['Ozone'].mean()

# Create a bar plot
plt.figure(figsize=(8, 5))
plt.bar(average_ozone_by_month.index, average_ozone_by_month.values, color='skyblue')
plt.xlabel("Month")
plt.ylabel("Average Ozone Level")
plt.title("Average Ozone Levels by Month")
plt.xticks(range(1, 13))  # Months are typically 1 through 12
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Insight-The trend suggests that ozone levels are higher during warmer months, likely due to increased sunlight and heat, which facilitate the formation of ground-level ozone. Lower values are observed in spring (May) and early fall (September), with levels dropping significantly outside the summer peak.

# %% [markdown]
# SCATTER PLOT OF OZONE VS WIND

# %%
# --- Scatter Plot: Ozone vs Wind ---
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Ozone', y='Wind', data=df, hue='Ozone_Category', palette='coolwarm')
plt.title('Scatter Plot of Ozone vs Wind Speed')
plt.show()

# %% [markdown]
# Insight-The scatter plot shows the relationship between ozone levels and wind speed. The x-axis represents the wind speed, while the y-axis represents the ozone level. The different colors represent the ozone categories.

# %% [markdown]
# **HEATMAP**

# %%
# --- Heat Map: Correlation Between Variables ---
plt.figure(figsize=(10, 8))
corr_matrix = df[['Ozone', 'Solar.R', 'Wind', 'Temp']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Heat Map of Variable Correlations')
plt.show()

# %% [markdown]
# Insight-The heatmap shows the correlation between different variables: Ozone, Solar.R, Wind, and Temp. The color intensity represents the strength and direction of the correlation.

# %% [markdown]
# LINE GRAPH

# %%
# Line graph for 'Ozone', 'Solar.R', 'Wind', and 'Temp'
plt.figure(figsize=(12, 6))

# Plot each variable as a line
plt.plot(df['Ozone'], label='Ozone', marker='o', linestyle='-', color='blue')


# Add labels and title
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Line Graph of Ozone, Solar.R, Wind, and Temp')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
# Line graph for 'Ozone', 'Solar.R', 'Wind', and 'Temp'
plt.figure(figsize=(12, 6))

# Plot each variable as a line
plt.plot(df['Solar.R'], label='Solar Radiation', marker='s', linestyle='-', color='orange')



# Add labels and title
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Line Graph of Ozone, Solar.R, Wind, and Temp')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# Insight-The line graph shows the trends of Ozone, Solar.R, Wind, and Temp over time. The x-axis represents the index (time), while the y-axis represents the values of these variables.

# %% [markdown]
# CONCLUSION :
# In conclusion, the analysis of air quality data has provided valuable insights into the relationship between meteorological factors and ozone levels. Through data cleaning, we ensured the reliability of our findings by addressing missing values. The distribution of ozone levels revealed a concerning prevalence of high and moderate categories, indicating potential risks to public health. Visualizations highlighted notable relationships between wind speed, temperature, and ozone concentrations, suggesting that meteorological conditions significantly influence air quality.

# %% [markdown]
# RECOMMENDATION:
# Based on the findings of this analysis, several recommendations can be made to enhance air quality and mitigate ozone pollution. First, it is crucial to implement regular monitoring of ozone levels alongside associated meteorological variables to identify trends and patterns over time, allowing for timely public warnings during high ozone events. Public awareness campaigns should also be established to educate the community about the health effects of ozone pollution, particularly targeting vulnerable populations such as children, the elderly, and individuals with preexisting health conditions, and advising them to limit outdoor activities during peak ozone periods.
